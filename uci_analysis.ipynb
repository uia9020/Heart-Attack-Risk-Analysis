# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('heart_disease_uci.csv',encoding='ascii')

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
plt.figure(figsize=(10,6),facecolor='white')
sns.histplot(data=df['age'],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df['cp'].value_counts(normalize=True)*100
# Out:
# cp
# asymptomatic       53.913043
# non-anginal        22.173913
# atypical angina    18.913043
# typical angina      5.000000
# Name: proportion, dtype: float64

# %%
df.groupby('cp')['sex'].value_counts().unstack()
# Out:
# sex              Female  Male
# cp
# asymptomatic         70   426
# atypical angina      61   113
# non-anginal          53   151
# typical angina       10    36

# %%
df.groupby('cp')['num'].value_counts()
# Out:
# cp               num
# asymptomatic     1      197
#                  0      104
#                  2       89
#                  3       83
#                  4       23
# atypical angina  0      150
#                  1       19
#                  3        3
#                  2        2
# non-anginal      0      131
#                  1       37
#                  3       18
#                  2       14
#                  4        4
# typical angina   0       26
#                  1       12
#                  2        4
#                  3        3
#                  4        1
# Name: count, dtype: int64

# %%
cp_counts=df.groupby('cp')['num'].value_counts().unstack()

# %%
cp_counts
# Out:
# num                  0      1     2     3     4
# cp
# asymptomatic     104.0  197.0  89.0  83.0  23.0
# atypical angina  150.0   19.0   2.0   3.0   NaN
# non-anginal      131.0   37.0  14.0  18.0   4.0
# typical angina    26.0   12.0   4.0   3.0   1.0

# %%
plt.figure(figsize=(10,6),facecolor='white')
cp_counts.plot(kind='bar')
plt.title('Chest Pain Type fs Number of Cases')
plt.xlabel('Chest Pain Type')
plt.ylabel('Number of Cases')
plt.show()

# %%
df_num4=df[df['num']==4]

# %%
df_num4['cp'].value_counts()
# Out:
# cp
# asymptomatic      23
# non-anginal        4
# typical angina     1
# Name: count, dtype: int64

# %%
cp_counts_num4=df_num4['cp'].value_counts()

# %%
cp_counts_num4
# Out:
# cp
# asymptomatic      23
# non-anginal        4
# typical angina     1
# Name: count, dtype: int64

# %%
cp_counts_num4.plot(kind='bar',color='skyblue')

plt.title('Occurences of Chest Pain Types for num ==4')
plt.xlabel('Chest Pain type')
plt.ylabel('Occurences')
plt.xticks(rotation=45)
plt.show()

# %%
df[df['num']==3]['cp'].value_counts().plot(kind='bar',color='green')
plt.title('Occurences of Chest pain types for num==3')
plt.xlabel('Chest Pain Type')
plt.ylabel('Occurences')
plt.xticks(rotation=45)
plt.show()

# %%
df[df['num']==2]['cp'].value_counts().plot(kind='bar',color='green')
plt.title('Occurences of Chest pain types for num==2')
plt.xlabel('Chest Pain Type')
plt.ylabel('Occurences')
plt.xticks(rotation=45)
plt.show()

# %%
df[df['num']==1]['cp'].value_counts().plot(kind='bar',color='green')
plt.title('Occurences of Chest pain types for num==1')
plt.xlabel('Chest Pain Type')
plt.ylabel('Occurences')
plt.xticks(rotation=45)
plt.show()

# %%
df[df['num']==0]['cp'].value_counts().plot(kind='bar',color='green')
plt.title('Occurences of Chest pain types for num==0')
plt.xlabel('Chest Pain Type')
plt.ylabel('Occurences')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,12), facecolor='white')

plt.subplot(3,2,1)
df[df['num']==4]['cp'].value_counts().plot(kind='bar',color='skyblue')
plt.title('Occurences of Chest pain types for num==3')
plt.xlabel('Chest Pain Type')
plt.ylabel('Occurences')
plt.xticks(rotation=0)

plt.subplot(3,2,2)

df[df['num']==3]['cp'].value_counts().plot(kind='bar',color='yellowgreen')
plt.title('Occurences of Chest pain types for num==3')
plt.xlabel('Chest Pain Type')
plt.ylabel('Occurences')
plt.xticks(rotation=0)

plt.subplot(3,2,3)

df[df['num']==2]['cp'].value_counts().plot(kind='bar',color='orange')
plt.title('Occurences of Chest pain types for num==2')
plt.xlabel('Chest Pain Type')
plt.ylabel('Occurences')
plt.xticks(rotation=0)

plt.subplot(3,2,4)

df[df['num']==1]['cp'].value_counts().plot(kind='bar',color='brown')
plt.title('Occurences of Chest pain types for num==1')
plt.xlabel('Chest Pain Type')
plt.ylabel('Occurences')
plt.xticks(rotation=0)

plt.subplot(3,2,5)

df[df['num']==0]['cp'].value_counts().plot(kind='bar',color='green')
plt.title('Occurences of Chest pain types for num==0')
plt.xlabel('Chest Pain Type')
plt.ylabel('Occurences')
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
df['cp'].value_counts()
# Out:
# cp
# asymptomatic       496
# non-anginal        204
# atypical angina    174
# typical angina      46
# Name: count, dtype: int64

# %%
df.groupby('cp')['num'].value_counts()
# Out:
# cp               num
# asymptomatic     1      197
#                  0      104
#                  2       89
#                  3       83
#                  4       23
# atypical angina  0      150
#                  1       19
#                  3        3
#                  2        2
# non-anginal      0      131
#                  1       37
#                  3       18
#                  2       14
#                  4        4
# typical angina   0       26
#                  1       12
#                  2        4
#                  3        3
#                  4        1
# Name: count, dtype: int64

# %%
df.groupby(['cp','num']).size().unstack(fill_value=0)
# Out:
# num                0    1   2   3   4
# cp
# asymptomatic     104  197  89  83  23
# atypical angina  150   19   2   3   0
# non-anginal      131   37  14  18   4
# typical angina    26   12   4   3   1

# %%
conditional_prob_num=df.groupby('num')['cp'].value_counts(normalize=True).unstack(fill_value=0)

# %%
conditional_prob_num
# Out:
# cp   asymptomatic  atypical angina  non-anginal  typical angina
# num
# 0        0.253041         0.364964     0.318735        0.063260
# 1        0.743396         0.071698     0.139623        0.045283
# 2        0.816514         0.018349     0.128440        0.036697
# 3        0.775701         0.028037     0.168224        0.028037
# 4        0.821429         0.000000     0.142857        0.035714

# %%
conditional_prob_cp=df.groupby('cp')['num'].value_counts(normalize=True).unstack(fill_value=0)

# %%
conditional_prob_cp
# Out:
# num                     0         1         2         3         4
# cp
# asymptomatic     0.209677  0.397177  0.179435  0.167339  0.046371
# atypical angina  0.862069  0.109195  0.011494  0.017241  0.000000
# non-anginal      0.642157  0.181373  0.068627  0.088235  0.019608
# typical angina   0.565217  0.260870  0.086957  0.065217  0.021739

# %%
cp_df=df[['cp','num']]

# %%
cp_mapping={'typical angina':0,'atypical angina':1,'non-anginal':3,'asymptomatic':4}

# %%
cp_df_mapped=pd.DataFrame()
cp_df['cp_numeric']=cp_df['cp'].map(cp_mapping)
# Out:
# C:\Users\amila.w\AppData\Local\Temp\ipykernel_51108\869314795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cp_df['cp_numeric']=cp_df['cp'].map(cp_mapping)

# %%
cp_df
# Out:
#                   cp  num  cp_numeric
# 0     typical angina    0           0
# 1       asymptomatic    2           4
# 2       asymptomatic    1           4
# 3        non-anginal    0           3
# 4    atypical angina    0           1
# ..               ...  ...         ...
# 915     asymptomatic    1           4
# 916   typical angina    0           0
# 917     asymptomatic    2           4
# 918     asymptomatic    0           4
# 919  atypical angina    1           1
#
# [920 rows x 3 columns]

# %%
cp_num_corr=cp_df['cp_numeric'].corr(cp_df['num'])

# %%
cp_num_corr
# Out:
# 0.39119117890505756
